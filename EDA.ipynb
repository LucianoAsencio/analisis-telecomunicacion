# %% [markdown]
# Esta parte del proyecto, está orientada en realizar un EDA al dataset principal, intentando sacar el mayor provecho posible al mismo y también a corregir posibles errores en los datos.

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/AMD/Desktop/Proyectos_individuales/Proyecto de análisis de telecomunicaciones/datasets/Internet_Penetracion (5).csv')

# %%
df.info()

#Vemos que provincia y accesos por cada 100 hogares son tipo object, y necesitamos que sean tipo string
# y tipo float respectivamente.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           792 non-null    int64
#  1   Trimestre                     792 non-null    int64
#  2   Provincia                     792 non-null    object
#  3   Accesos por cada 100 hogares  792 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 24.9+ KB

# %%
for n in df.columns:
    print(df[n].unique())

#Revisamos si hay errores en los datos y todo parece normal
# Out:
# [2022 2021 2020 2019 2018 2017 2016 2015 2014]
# [1 4 3 2]
# ['Buenos Aires' 'Capital Federal' 'Catamarca' 'Chaco' 'Chubut' 'Córdoba'
#  'Corrientes' 'Entre Ríos' 'Formosa' 'Jujuy' 'La Pampa' 'La Rioja'
#  'Mendoza' 'Misiones' 'Neuquén' 'Río Negro' 'Salta' 'San Juan' 'San Luis'
#  'Santa Cruz' 'Santa Fe' 'Santiago Del Estero' 'Tierra Del Fuego'
#  'Tucumán']
# ['76,08' '111,8' '58,21' '44,06' '88,05' '85,76' '47,64' '63,7' '34,96'
#  '58,06' '91,66' '78,77' '48,74' '49,04' '74,17' '67,04' '56,11' '43,55'
#  '80,72' '43,34' '77,3' '47,17' '98,29' '57,39' '75,66' '111,27' '55,25'
#  '44,05' '82,57' '84,51' '45,51' '63,16' '34,45' '56,92' '89,57' '77,92'
#  '47,51' '49,06' '73,3' '65,69' '56,81' '39,59' '80,3' '43,05' '77,09'
#  '47,05' '98,4' '55,93' '71,68' '52,71' '42,96' '80,71' '81,28' '44,9'
#  '62,18' '33,96' '55,69' '84,28' '77,26' '45,55' '45,57' '69,71' '61,97'
#  '55,96' '39,46' '79,87' '43,75' '75,02' '47' '94,95' '54,64' '70'
# ...

# %%
df['Provincia'] = df['Provincia'].astype("string")

# %%
df['Accesos por cada 100 hogares'] = df['Accesos por cada 100 hogares'].str.replace(',','.')
df['Accesos por cada 100 hogares'] = df['Accesos por cada 100 hogares'].astype(float)

# %%
df.info()

#Ahora que ya tenemos los datos arreglados, pasamos a PowerBI para realizar el análisis más completo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           792 non-null    int64
#  1   Trimestre                     792 non-null    int64
#  2   Provincia                     792 non-null    string
#  3   Accesos por cada 100 hogares  792 non-null    float64
# dtypes: float64(1), int64(2), string(1)
# memory usage: 24.9 KB

# %%
df.to_csv('Penetracion_Cada_100_Hogares')
